# %% [markdown]
# <a href="https://colab.research.google.com/github/sevaux/Erasmus-2026-Antwerpen/blob/main/course-solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
function generate_cities(n)
    return rand(0:100,n, 2)
end

# Generate a fixed set of cities for testing
CITIES = generate_cities(15)
